# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.293789
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.151102 analytic: 1.151102, relative error: 3.691093e-09
# numerical: -0.018613 analytic: -0.018613, relative error: 5.129105e-07
# numerical: 1.081506 analytic: 1.081506, relative error: 6.996590e-09
# numerical: -2.331768 analytic: -2.331768, relative error: 4.836263e-08
# numerical: 1.125086 analytic: 1.125086, relative error: 5.086213e-08
# numerical: 0.614880 analytic: 0.614880, relative error: 8.721137e-08
# numerical: -2.567999 analytic: -2.567999, relative error: 1.185149e-09
# numerical: -1.621663 analytic: -1.621663, relative error: 6.612558e-08
# numerical: 0.829614 analytic: 0.829614, relative error: 1.040629e-07
# numerical: 0.938637 analytic: 0.938637, relative error: 2.393545e-08
# numerical: -0.307765 analytic: -0.307765, relative error: 1.941479e-08
# numerical: -1.052284 analytic: -1.052284, relative error: 2.786995e-08
# numerical: 1.437912 analytic: 1.437912, relative error: 6.452294e-09
# numerical: -2.790604 analytic: -2.790605, relative error: 2.707236e-08
# numerical: 1.373637 analytic: 1.373637, relative error: 1.586434e-08
# numerical: 0.449858 analytic: 0.449858, relative error: 2.150962e-08
# numerical: 0.101397 analytic: 0.101397, relative error: 2.481460e-08
# numerical: 1.741259 analytic: 1.741259, relative error: 3.556620e-09
# numerical: 0.701399 analytic: 0.701399, relative error: 2.684359e-09
# numerical: 0.395797 analytic: 0.395797, relative error: 9.176221e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.293789e+00 computed in 0.096790s
# vectorized loss: 2.293789e+00 computed in 0.005770s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = np.arange(45000, 55000, 1000)

for lr in learning_rates :
    for reg in regularization_strengths:
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=reg, num_iters=1500, verbose=True)
        y_train_pred = softmax.predict(X_train)
        train_accuracy = np.mean(y_train_pred == y_train)
        y_val_pred = softmax.predict(X_val)
        val_accuracy = np.mean(y_val_pred == y_val)
        if val_accuracy > best_val :
            best_val = val_accuracy 
            best_softmax = softmax 
        results[(lr, reg)] = train_accuracy, val_accuracy
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 1500: loss 691.298996
# iteration 100 / 1500: loss 280.868288
# iteration 200 / 1500: loss 114.981713
# iteration 300 / 1500: loss 47.725629
# iteration 400 / 1500: loss 20.555665
# iteration 500 / 1500: loss 9.518371
# iteration 600 / 1500: loss 5.076794
# iteration 700 / 1500: loss 3.366538
# iteration 800 / 1500: loss 2.576545
# iteration 900 / 1500: loss 2.333395
# iteration 1000 / 1500: loss 2.179336
# iteration 1100 / 1500: loss 2.078979
# iteration 1200 / 1500: loss 2.089614
# iteration 1300 / 1500: loss 2.156239
# iteration 1400 / 1500: loss 2.063513
# iteration 0 / 1500: loss 711.296500
# iteration 100 / 1500: loss 282.723440
# iteration 200 / 1500: loss 113.368928
# iteration 300 / 1500: loss 46.149077
# iteration 400 / 1500: loss 19.661466
# iteration 500 / 1500: loss 8.982395
# iteration 600 / 1500: loss 4.830551
# iteration 700 / 1500: loss 3.247038
# iteration 800 / 1500: loss 2.537712
# iteration 900 / 1500: loss 2.213542
# iteration 1000 / 1500: loss 2.160534
# iteration 1100 / 1500: loss 2.128983
# iteration 1200 / 1500: loss 2.143267
# iteration 1300 / 1500: loss 2.129509
# iteration 1400 / 1500: loss 2.080484
# iteration 0 / 1500: loss 732.638059
# iteration 100 / 1500: loss 285.482421
# iteration 200 / 1500: loss 112.245093
# iteration 300 / 1500: loss 44.882388
# iteration 400 / 1500: loss 18.724324
# iteration 500 / 1500: loss 8.495280
# iteration 600 / 1500: loss 4.579081
# iteration 700 / 1500: loss 3.074338
# iteration 800 / 1500: loss 2.446110
# iteration 900 / 1500: loss 2.232394
# iteration 1000 / 1500: loss 2.165689
# iteration 1100 / 1500: loss 2.061162
# iteration 1200 / 1500: loss 2.117621
# iteration 1300 / 1500: loss 2.061576
# iteration 1400 / 1500: loss 2.077135
# iteration 0 / 1500: loss 738.221763
# iteration 100 / 1500: loss 282.106436
# iteration 200 / 1500: loss 108.791818
# iteration 300 / 1500: loss 42.693428
# iteration 400 / 1500: loss 17.599049
# iteration 500 / 1500: loss 8.013527
# iteration 600 / 1500: loss 4.371391
# iteration 700 / 1500: loss 3.000003
# iteration 800 / 1500: loss 2.447686
# iteration 900 / 1500: loss 2.212145
# iteration 1000 / 1500: loss 2.161368
# iteration 1100 / 1500: loss 2.129377
# iteration 1200 / 1500: loss 2.117964
# iteration 1300 / 1500: loss 2.035628
# iteration 1400 / 1500: loss 2.027767
# iteration 0 / 1500: loss 753.858700
# iteration 100 / 1500: loss 282.595260
# iteration 200 / 1500: loss 106.579935
# iteration 300 / 1500: loss 41.210503
# iteration 400 / 1500: loss 16.697598
# iteration 500 / 1500: loss 7.585756
# iteration 600 / 1500: loss 4.096591
# iteration 700 / 1500: loss 2.820017
# iteration 800 / 1500: loss 2.360243
# iteration 900 / 1500: loss 2.203771
# iteration 1000 / 1500: loss 2.144334
# iteration 1100 / 1500: loss 2.166302
# iteration 1200 / 1500: loss 2.045046
# iteration 1300 / 1500: loss 2.156434
# iteration 1400 / 1500: loss 2.024669
# iteration 0 / 1500: loss 777.407970
# iteration 100 / 1500: loss 285.444413
# iteration 200 / 1500: loss 105.668778
# iteration 300 / 1500: loss 39.935393
# iteration 400 / 1500: loss 15.973672
# iteration 500 / 1500: loss 7.137232
# iteration 600 / 1500: loss 4.006681
# iteration 700 / 1500: loss 2.766568
# iteration 800 / 1500: loss 2.387743
# iteration 900 / 1500: loss 2.122675
# iteration 1000 / 1500: loss 2.064949
# iteration 1100 / 1500: loss 2.061184
# iteration 1200 / 1500: loss 2.127336
# iteration 1300 / 1500: loss 2.082744
# iteration 1400 / 1500: loss 2.117219
# iteration 0 / 1500: loss 790.838470
# iteration 100 / 1500: loss 284.022591
# iteration 200 / 1500: loss 103.162680
# iteration 300 / 1500: loss 38.388831
# iteration 400 / 1500: loss 15.087101
# iteration 500 / 1500: loss 6.722229
# iteration 600 / 1500: loss 3.717976
# iteration 700 / 1500: loss 2.706522
# iteration 800 / 1500: loss 2.322483
# iteration 900 / 1500: loss 2.151880
# iteration 1000 / 1500: loss 2.083414
# iteration 1100 / 1500: loss 2.128277
# iteration 1200 / 1500: loss 2.142608
# iteration 1300 / 1500: loss 2.076327
# iteration 1400 / 1500: loss 2.085483
# iteration 0 / 1500: loss 791.742983
# iteration 100 / 1500: loss 279.099157
# iteration 200 / 1500: loss 99.508610
# iteration 300 / 1500: loss 36.306976
# iteration 400 / 1500: loss 14.155302
# iteration 500 / 1500: loss 6.337932
# iteration 600 / 1500: loss 3.589095
# iteration 700 / 1500: loss 2.644975
# iteration 800 / 1500: loss 2.293772
# iteration 900 / 1500: loss 2.153386
# iteration 1000 / 1500: loss 2.079395
# iteration 1100 / 1500: loss 2.089251
# iteration 1200 / 1500: loss 2.086909
# iteration 1300 / 1500: loss 2.094369
# iteration 1400 / 1500: loss 2.129125
# iteration 0 / 1500: loss 825.261363
# iteration 100 / 1500: loss 285.449229
# iteration 200 / 1500: loss 99.564797
# iteration 300 / 1500: loss 35.712096
# iteration 400 / 1500: loss 13.700631
# iteration 500 / 1500: loss 6.086133
# iteration 600 / 1500: loss 3.547786
# iteration 700 / 1500: loss 2.512339
# iteration 800 / 1500: loss 2.290023
# iteration 900 / 1500: loss 2.172549
# iteration 1000 / 1500: loss 2.137004
# iteration 1100 / 1500: loss 2.093745
# iteration 1200 / 1500: loss 2.154083
# iteration 1300 / 1500: loss 2.104069
# iteration 1400 / 1500: loss 2.097141
# iteration 0 / 1500: loss 825.617510
# iteration 100 / 1500: loss 279.967935
# iteration 200 / 1500: loss 95.737545
# iteration 300 / 1500: loss 33.758850
# iteration 400 / 1500: loss 12.821944
# iteration 500 / 1500: loss 5.731252
# iteration 600 / 1500: loss 3.338139
# iteration 700 / 1500: loss 2.522013
# iteration 800 / 1500: loss 2.230244
# iteration 900 / 1500: loss 2.111400
# iteration 1000 / 1500: loss 2.118038
# iteration 1100 / 1500: loss 2.160942
# iteration 1200 / 1500: loss 2.095133
# iteration 1300 / 1500: loss 2.083866
# iteration 1400 / 1500: loss 2.067483
# iteration 0 / 1500: loss 705.269993
# iteration 100 / 1500: loss 9.325223
# iteration 200 / 1500: loss 2.110652
# iteration 300 / 1500: loss 2.079720
# iteration 400 / 1500: loss 2.064558
# iteration 500 / 1500: loss 2.114319
# iteration 600 / 1500: loss 2.087523
# iteration 700 / 1500: loss 2.082782
# iteration 800 / 1500: loss 2.060330
# iteration 900 / 1500: loss 2.015487
# iteration 1000 / 1500: loss 2.120907
# iteration 1100 / 1500: loss 2.095646
# iteration 1200 / 1500: loss 2.087113
# iteration 1300 / 1500: loss 2.035390
# iteration 1400 / 1500: loss 2.027532
# iteration 0 / 1500: loss 708.010763
# iteration 100 / 1500: loss 8.752981
# iteration 200 / 1500: loss 2.163158
# iteration 300 / 1500: loss 2.060318
# iteration 400 / 1500: loss 2.091421
# iteration 500 / 1500: loss 2.132769
# iteration 600 / 1500: loss 2.075146
# iteration 700 / 1500: loss 2.110663
# iteration 800 / 1500: loss 2.063846
# iteration 900 / 1500: loss 2.110417
# iteration 1000 / 1500: loss 2.082407
# iteration 1100 / 1500: loss 2.130777
# iteration 1200 / 1500: loss 2.132420
# iteration 1300 / 1500: loss 2.069784
# iteration 1400 / 1500: loss 2.055442
# iteration 0 / 1500: loss 718.884738
# iteration 100 / 1500: loss 8.101748
# iteration 200 / 1500: loss 2.085579
# iteration 300 / 1500: loss 2.114124
# iteration 400 / 1500: loss 2.072035
# iteration 500 / 1500: loss 2.083132
# iteration 600 / 1500: loss 2.086397
# iteration 700 / 1500: loss 2.065438
# iteration 800 / 1500: loss 2.082387
# iteration 900 / 1500: loss 2.063680
# iteration 1000 / 1500: loss 2.138627
# iteration 1100 / 1500: loss 2.080400
# iteration 1200 / 1500: loss 2.073499
# iteration 1300 / 1500: loss 2.139627
# iteration 1400 / 1500: loss 2.088933
# iteration 0 / 1500: loss 745.636830
# iteration 100 / 1500: loss 7.768059
# iteration 200 / 1500: loss 2.107798
# iteration 300 / 1500: loss 2.074183
# iteration 400 / 1500: loss 2.071322
# iteration 500 / 1500: loss 2.036518
# iteration 600 / 1500: loss 2.097172
# iteration 700 / 1500: loss 2.071275
# iteration 800 / 1500: loss 2.101954
# iteration 900 / 1500: loss 2.104414
# iteration 1000 / 1500: loss 2.092879
# iteration 1100 / 1500: loss 2.079035
# iteration 1200 / 1500: loss 2.096866
# iteration 1300 / 1500: loss 2.094038
# iteration 1400 / 1500: loss 2.186998
# iteration 0 / 1500: loss 754.954746
# iteration 100 / 1500: loss 7.262945
# iteration 200 / 1500: loss 2.165676
# iteration 300 / 1500: loss 2.081630
# iteration 400 / 1500: loss 2.045852
# iteration 500 / 1500: loss 2.139190
# iteration 600 / 1500: loss 2.094866
# iteration 700 / 1500: loss 2.062893
# iteration 800 / 1500: loss 2.059693
# iteration 900 / 1500: loss 2.105215
# iteration 1000 / 1500: loss 2.064580
# iteration 1100 / 1500: loss 2.061974
# iteration 1200 / 1500: loss 2.133681
# iteration 1300 / 1500: loss 2.074464
# iteration 1400 / 1500: loss 2.089983
# iteration 0 / 1500: loss 773.351465
# iteration 100 / 1500: loss 6.881156
# iteration 200 / 1500: loss 2.173156
# iteration 300 / 1500: loss 2.094029
# iteration 400 / 1500: loss 2.065225
# iteration 500 / 1500: loss 2.093842
# iteration 600 / 1500: loss 2.053910
# iteration 700 / 1500: loss 2.109703
# iteration 800 / 1500: loss 2.116791
# iteration 900 / 1500: loss 2.080492
# iteration 1000 / 1500: loss 2.102391
# iteration 1100 / 1500: loss 2.074920
# iteration 1200 / 1500: loss 2.124061
# iteration 1300 / 1500: loss 2.106654
# iteration 1400 / 1500: loss 2.082808
# iteration 0 / 1500: loss 788.513844
# iteration 100 / 1500: loss 6.502039
# iteration 200 / 1500: loss 2.047109
# iteration 300 / 1500: loss 2.094140
# iteration 400 / 1500: loss 2.098286
# iteration 500 / 1500: loss 2.128401
# iteration 600 / 1500: loss 2.057905
# iteration 700 / 1500: loss 2.081440
# iteration 800 / 1500: loss 2.074075
# iteration 900 / 1500: loss 2.068463
# iteration 1000 / 1500: loss 2.172409
# iteration 1100 / 1500: loss 2.107397
# iteration 1200 / 1500: loss 2.143183
# iteration 1300 / 1500: loss 2.035205
# iteration 1400 / 1500: loss 2.110548
# iteration 0 / 1500: loss 797.576959
# iteration 100 / 1500: loss 6.107626
# iteration 200 / 1500: loss 2.151050
# iteration 300 / 1500: loss 2.078749
# iteration 400 / 1500: loss 2.180538
# iteration 500 / 1500: loss 2.109701
# iteration 600 / 1500: loss 2.070500
# iteration 700 / 1500: loss 2.118194
# iteration 800 / 1500: loss 2.046242
# iteration 900 / 1500: loss 2.099838
# iteration 1000 / 1500: loss 2.076140
# iteration 1100 / 1500: loss 2.121232
# iteration 1200 / 1500: loss 2.132346
# iteration 1300 / 1500: loss 2.091131
# iteration 1400 / 1500: loss 2.055251
# iteration 0 / 1500: loss 808.858334
# iteration 100 / 1500: loss 5.737078
# iteration 200 / 1500: loss 2.106235
# iteration 300 / 1500: loss 2.097806
# iteration 400 / 1500: loss 2.093379
# iteration 500 / 1500: loss 2.083812
# iteration 600 / 1500: loss 2.124357
# iteration 700 / 1500: loss 2.165181
# iteration 800 / 1500: loss 2.090044
# iteration 900 / 1500: loss 2.063858
# iteration 1000 / 1500: loss 2.107129
# iteration 1100 / 1500: loss 1.998388
# iteration 1200 / 1500: loss 2.074963
# iteration 1300 / 1500: loss 2.128628
# iteration 1400 / 1500: loss 2.025737
# iteration 0 / 1500: loss 828.660692
# iteration 100 / 1500: loss 5.526344
# iteration 200 / 1500: loss 2.104129
# iteration 300 / 1500: loss 2.100135
# iteration 400 / 1500: loss 2.130378
# iteration 500 / 1500: loss 2.094963
# iteration 600 / 1500: loss 2.075715
# iteration 700 / 1500: loss 2.068624
# iteration 800 / 1500: loss 2.120511
# iteration 900 / 1500: loss 2.076995
# iteration 1000 / 1500: loss 2.057924
# iteration 1100 / 1500: loss 2.154302
# iteration 1200 / 1500: loss 2.090160
# iteration 1300 / 1500: loss 2.085122
# iteration 1400 / 1500: loss 2.101952
# lr 1.000000e-07 reg 4.500000e+04 train accuracy: 0.333204 val accuracy: 0.350000
# lr 1.000000e-07 reg 4.600000e+04 train accuracy: 0.324531 val accuracy: 0.340000
# lr 1.000000e-07 reg 4.700000e+04 train accuracy: 0.329653 val accuracy: 0.344000
# lr 1.000000e-07 reg 4.800000e+04 train accuracy: 0.329020 val accuracy: 0.340000
# lr 1.000000e-07 reg 4.900000e+04 train accuracy: 0.325327 val accuracy: 0.333000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.328571 val accuracy: 0.348000
# lr 1.000000e-07 reg 5.100000e+04 train accuracy: 0.330612 val accuracy: 0.351000
# lr 1.000000e-07 reg 5.200000e+04 train accuracy: 0.330388 val accuracy: 0.347000
# lr 1.000000e-07 reg 5.300000e+04 train accuracy: 0.330102 val accuracy: 0.349000
# lr 1.000000e-07 reg 5.400000e+04 train accuracy: 0.326939 val accuracy: 0.339000
# lr 5.000000e-07 reg 4.500000e+04 train accuracy: 0.329122 val accuracy: 0.345000
# lr 5.000000e-07 reg 4.600000e+04 train accuracy: 0.329265 val accuracy: 0.341000
# lr 5.000000e-07 reg 4.700000e+04 train accuracy: 0.335673 val accuracy: 0.351000
# lr 5.000000e-07 reg 4.800000e+04 train accuracy: 0.325327 val accuracy: 0.338000
# lr 5.000000e-07 reg 4.900000e+04 train accuracy: 0.325776 val accuracy: 0.346000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.330347 val accuracy: 0.342000
# lr 5.000000e-07 reg 5.100000e+04 train accuracy: 0.319143 val accuracy: 0.326000
# lr 5.000000e-07 reg 5.200000e+04 train accuracy: 0.326245 val accuracy: 0.338000
# lr 5.000000e-07 reg 5.300000e+04 train accuracy: 0.325286 val accuracy: 0.336000
# lr 5.000000e-07 reg 5.400000e+04 train accuracy: 0.330020 val accuracy: 0.347000
# best validation accuracy achieved during cross-validation: 0.351000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.341000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
